# %% [markdown]
# Автор: Лейман М.А.
# Дата создания: 13.06.2025

# %% [markdown]
# # Визуализация изображений с боксами

# %%
from preprocess import find_images_with_class
from visualize_img import visualize_img, visualize_img_full
import os

# %%
target_path = "dataset_full_1/labels/train/"

# Получаем текущую рабочую папку  
current_directory = os.getcwd()  
path_dataset = os.path.join(current_directory, "dataset")
label_dir = os.path.join(path_dataset, target_path)  

find_images_with_class(label_dir, target_class=3)
# Out:
# ['00000099_1_crop0.jpg',
#  '00000099_tiny.jpg',
#  '00000100_1_crop0.jpg',
#  '00000100_tiny.jpg',
#  'P0001_1_crop0.jpg',
#  'P0001_1_crop1.jpg',
#  'P0001_1_crop10.jpg',
#  'P0001_1_crop11.jpg',
#  'P0001_1_crop12.jpg',
#  'P0001_1_crop13.jpg',
#  'P0001_1_crop14.jpg',
#  'P0001_1_crop15.jpg',
#  'P0001_1_crop16.jpg',
#  'P0001_1_crop17.jpg',
#  'P0001_1_crop18.jpg',
#  'P0001_1_crop19.jpg',
#  'P0001_1_crop2.jpg',
#  'P0001_1_crop20.jpg',
#  'P0001_1_crop21.jpg',
#  'P0001_1_crop22.jpg',
#  'P0001_1_crop23.jpg',
#  'P0001_1_crop24.jpg',
#  'P0001_1_crop25.jpg',
#  'P0001_1_crop26.jpg',
#  'P0001_1_crop27.jpg',
#  'P0001_1_crop28.jpg',
#  'P0001_1_crop3.jpg',
#  'P0001_1_crop4.jpg',
#  'P0001_1_crop5.jpg',
#  'P0001_1_crop6.jpg',
#  'P0001_1_crop7.jpg',
#  'P0001_1_crop8.jpg',
#  'P0001_1_crop9.jpg',
#  'P0001_tiny.jpg',
#  'P0019_0_crop0.jpg',
#  'P0019_0_crop1.jpg',
#  'P0019_0_crop10.jpg',
#  'P0019_0_crop11.jpg',
#  'P0019_0_crop12.jpg',
#  'P0019_0_crop13.jpg',
# ...

# %% [markdown]
# ### Просмотр.  Обработка датасета. Исправление разметки.
#
# ![image.png](attachment:image.png)
#
# #### НЕ весь датасет размечен корректно

# %%
image_name = "490.jpg"  

images_path="/home/maksim/develops/python/devsTraining/zala_task/dataset/dataset_UAVOD/datasets_original/image"
labels_path="/home/maksim/develops/python/devsTraining/zala_task/dataset/dataset_UAVOD/datasets_original/target_yolo/"
visualize_img(image_name, images_path=images_path, labels_path=labels_path)
# Out:
# /home/maksim/develops/python/devsTraining/zala_task/dataset/dataset_UAVOD/datasets_original/image/490.jpg
# /home/maksim/develops/python/devsTraining/zala_task/dataset/dataset_UAVOD/datasets_original/target_yolo/490.txt

# %% [markdown]
# ## Просмотр изображений в цикле

# %%
images_path="/home/maksim/develops/python/devsTraining/zala_task/dataset/dataset_UAVOD/dataset_orign_2/image/"
labels_path="/home/maksim/develops/python/devsTraining/zala_task/dataset/dataset_UAVOD/dataset_orign_2/target/"

visualize_img_full(images_path=images_path, labels_path=labels_path, size_x = 12, size_y=12)
# Out:
# 1.jpg
# /home/maksim/develops/python/devsTraining/zala_task/dataset/dataset_UAVOD/dataset_orign_2/image/1.jpg
# /home/maksim/develops/python/devsTraining/zala_task/dataset/dataset_UAVOD/dataset_orign_2/target/1.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 images_path="/home/maksim/develops/python/devsTraining/zala_task/dataset/dataset_UAVOD/dataset_orign_2/image/"
#       2 labels_path="/home/maksim/develops/python/devsTraining/zala_task/dataset/dataset_UAVOD/dataset_orign_2/target/"
# ----> 4 visualize_img_full(images_path=images_path, labels_path=labels_path, size_x = 12, size_y=12)
#
# File ~/develops/python/Zala_task/Zala_task/visualize_img.py:93, in visualize_img_full(images_path, labels_path, size_x, size_y)
#      91     print(image_name)
# ...
